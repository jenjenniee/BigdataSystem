# %%
import pandas as pd
titanic_df = pd.read_csv("./titanic.csv")

# %%
import seaborn as sns
sns.catplot(x="Gender", hue="Survived", kind="count", data=titanic_df)
# Out:
# /Users/jingyeong/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
titanic_df.drop(columns='Name', inplace=True)
titanic_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
titanic_df.drop_duplicates(inplace=True)
titanic_df[titanic_df.duplicated()]
titanic_df.tail(10)
# Out:
#      PassengerId  Survived  Pclass  Gender   Age  SibSp  Parch  \
# 881          882         0       3    male  33.0      0      0
# 882          883         0       3  female  22.0      0      0
# 883          884         0       2    male  28.0      0      0
# 884          885         0       3    male  25.0      0      0
# 885          886         0       3  female  39.0      0      5
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 881            349257   7.8958   NaN        S
# 882              7552  10.5167   NaN        S
# 883  C.A./SOTON 34068  10.5000   NaN        S
# 884   SOTON/OQ 392076   7.0500   NaN        S
# 885            382652  29.1250   NaN        Q
# 886            211536  13.0000   NaN        S
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500   NaN        S
# 889            111369  30.0000  C148        C
# 890            370376   7.7500   NaN        Q

# %%
titanic_df.drop(columns=['PassengerId', 'Cabin', 'Ticket', 'Embarked'], inplace=True)
titanic_df.head(5)
# Out:
#    Survived  Pclass  Gender   Age  SibSp  Parch     Fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %%
titanic_df[titanic_df.duplicated()]
# Out:
#      Survived  Pclass  Gender   Age  SibSp  Parch     Fare
# 42          0       3    male   NaN      0      0   7.8958
# 47          1       3  female   NaN      0      0   7.7500
# 76          0       3    male   NaN      0      0   7.8958
# 77          0       3    male   NaN      0      0   8.0500
# 87          0       3    male   NaN      0      0   8.0500
# ..        ...     ...     ...   ...    ...    ...      ...
# 877         0       3    male  19.0      0      0   7.8958
# 878         0       3    male   NaN      0      0   7.8958
# 881         0       3    male  33.0      0      0   7.8958
# 884         0       3    male  25.0      0      0   7.0500
# 886         0       2    male  27.0      0      0  13.0000
#
# [114 rows x 7 columns]

# %%
import seaborn as sns
sns.heatmap(titanic_df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
titanic_df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Gender        0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# dtype: int64

# %%
titanic_df['Age'].fillna(titanic_df['Age'].mean(), inplace=True)
titanic_df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Gender      0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
titanic_df.dropna(inplace=True)
titanic_df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Gender      0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
titanic_df.head(10)
titanic_df.replace({'Gender': {'male': 0}}, inplace=True)
titanic_df.replace({'Gender': {'female': 1}}, inplace=True)

# %%
sns.boxplot(y = titanic_df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
titanic_df.drop(titanic_df[titanic_df.Fare >= 500].index, inplace=True)
sns.boxplot(y=titanic_df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
titanic_df.describe()
# Out:
#          Survived      Pclass      Gender         Age       SibSp       Parch  \
# count  888.000000  888.000000  888.000000  888.000000  888.000000  888.000000
# mean     0.381757    2.313063    0.352477   29.680083    0.524775    0.381757
# std      0.486091    0.834007    0.478011   13.019819    1.104186    0.806949
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    0.000000    0.000000
# 50%      0.000000    3.000000    0.000000   29.699118    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   35.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              Fare
# count  888.000000
# mean    30.582164
# std     41.176366
# min      0.000000
# 25%      7.895800
# 50%     14.454200
# 75%     30.771850
# max    263.000000

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
titanic_df[['Fare']] = scaler.fit_transform(titanic_df[['Fare']])
titanic_df.describe()
# Out:
#          Survived      Pclass      Gender         Age       SibSp       Parch  \
# count  888.000000  888.000000  888.000000  888.000000  888.000000  888.000000
# mean     0.381757    2.313063    0.352477   29.680083    0.524775    0.381757
# std      0.486091    0.834007    0.478011   13.019819    1.104186    0.806949
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    0.000000    0.000000
# 50%      0.000000    3.000000    0.000000   29.699118    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   35.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              Fare
# count  888.000000
# mean     0.116282
# std      0.156564
# min      0.000000
# 25%      0.030022
# 50%      0.054959
# 75%      0.117003
# max      1.000000

# %%
sns.heatmap(titanic_df.corr(), annot=True)
# Out:
# <Axes: >

# %%
x_columns = ['Pclass', 'Gender', 'Age', 'SibSp','Parch', 'Fare']
y_column = 'Survived'

X = titanic_df[x_columns]
y = titanic_df[y_column]

import numpy as np

X = np.array(X)
y = np.array(y)

print(X.shape)
print(y.shape)
# Out:
# (888, 6)
# (888,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,shuffle=False, random_state=333)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (621, 6) (267, 6) (621,) (267,)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

clf = DecisionTreeClassifier(max_depth = 4)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
cn = ['Unsurvived', 'Survived']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(clf, feature_names = x_columns, class_names=cn, filled = True);

# %%
from sklearn.metrics import *

acc = accuracy_score(y_test, y_pred)

print('Acc.: {}%'.format(np.round(acc * 100, 3)))
# Out:
# Acc.: 83.895%

# %%
x_columns = ['Pclass', 'Gender', 'Age', 'Parch','Fare']
X = scaler.fit_transform(titanic_df[x_columns])

print(X[:5, :])
print(X.shape)
# Out:
# [[1.         0.         0.27117366 0.         0.02756654]
#  [0.         1.         0.4722292  0.         0.27103916]
#  [1.         1.         0.32143755 0.         0.03013308]
#  [0.         1.         0.43453129 0.         0.20190114]
#  [1.         0.         0.43453129 0.         0.03060837]]
# (888, 5)

# %%
#학습시 fit 사용 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=False, random_state=333)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

clf = DecisionTreeClassifier(max_depth = 4)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred)

print('Acc.: {}%'.format(np.round(acc * 100, 3)))
# Out:
# (621, 5) (267, 5) (621,) (267,)
# Acc.: 83.895%
